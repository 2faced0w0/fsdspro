# %% [markdown]
# 1. Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

# %% [markdown]
# To find the value of T(2) for the given recurrence relation T(n)=3T(n-1)+12n with T(0) = 5, we can recursively substitute the values:
#
# 1. T(0)=5(given)
# 2. T(1)=3T(0)+12*1=3*5+12=15+12=27
# 3. T(2)=3T(1)+12*2=3*27+24=81+24=105
#
# Therefore, the value of T(2) is 105.

# %% [markdown]
# 2. Given a recurrence relation, solve it using the substitution method:
#
# a. T(n) = T(n-1) + c

# %% [markdown]
# T(n)=an+b
#
# base case: n=0 ; T(0)=a*0+b=b
#
# T(n)=T(n-1)+c
# => T(n-1)=T(n-2)+2c
#
# therefore T(n-2)=T(n-3)+3c
#
# T(n-k)=T(n-k+1)+kC
# let, n-k=1 =>k=n-1
#
# therefore,
# T(k)=T(n-(n-1)+1)+kC
# 	=1+(n-1)C
#     =O(n)

# %% [markdown]
# b. T(n) = 2T(n/2) + n

# %% [markdown]
# Given, T(n)=2T(n/2)+n; n>1
# T(n)=1; n==1
#
# T(n/2)=2T(n/4)+n/2
#
# T(n)=2^2[2T(n/2^3)+n/2^2]+2n
#
#     =2^kT(n/2^k)+kN
#
#     (let n/2^k = 1; => k=log2(n))
#
#     =n+nlogn
#
#     =O(nlogn)

# %% [markdown]
# c. T(n) = 2T(n/2) + c

# %% [markdown]
# given: T(n) = 2T(n/2) + c
#
# T(n/2)=2T(n/4)+c
#
# T(n)=2[2T(n/4)+c]+c
#
#     =2^3T(n/2^3)+3c
#
#     .
#
#     .(k times) (let n/2^k = 1; => k=log2(n))
#
#     .
#
#     =2^kT(n/2^k)+kC
#
#     =n.T(n/n)+kC
#
#     =n+kC
#
#     =O(n+logn)

# %% [markdown]
# d. T(n) = T(n/2) + c

# %% [markdown]
# given: T(n) = T(n/2) + c
#
# T(n/2)=T(n/4)+c
#
# T(n)=[2T(n/4)+c]+c
#
#     =T(n/2^3)+3c
#
#     .
#
#     .(k times) (let n/2^k = 1; => k=log2(n))
#
#     .
#
#     =T(n/2^k)+kC
#
#     =T(n/n)+kC
#
#     =O(logn)

# %% [markdown]
# 3. Given a recurrence relation, solve it using the recursive tree approach:

# %% [markdown]
# To solve the recurrence relation T(n) = 2T(n-1) + 1 using the recursive tree approach, let's break it down:
#
# The recurrence relation can be expressed as follows:
# T(n)=2T(n−1)+1
#
# To solve this recursively, we can visualize a tree where each level represents a recursive call:
#
# Level 1: T(n)
#
# Level 2:2T(n−1),2T(n−1)+1
#
# Level 3: 4T(n−2),4T(n−2)+1,4T(n−2)+1, and so on.
#
# This forms a binary tree, where each node has two children. The depth of the tree is
# n, and at each level, the number of nodes is a power of 2.
#
# Now, let's sum up the work done at each level:
#
# Level 1: 2^0 * 1
#
# Level 2: 2^1 * 1 +2^1 * 1
#
# Level 3: 2^2 * 1 + 2^2 * 1 + 2^2 * 1 and so on
#
# Generalizing this pattern, the work done at level i is 2^i * 1
#
# Now, summing up over all levels (i=0 to n), we get the total work done:
#
# T(n)= ∑2^i * 1
#
# This is a geometric series, and the sum can be expressed as:
# T(n)= 2^(n+1) - 1
#
# Therefore, the solution to the given recurrence relation is:
#
# 0(2^n)

# %% [markdown]
# b. T(n) = 2T(n/2) + n

# %% [markdown]
# To solve the recurrence relation T(n) = 2T(n-1) + 1 using the recursive tree approach, let's break it down:
#
# The recurrence relation can be expressed as follows:
# T(n)=2T(n−1)+1
#
# To solve this recursively, we can visualize a tree where each level represents a recursive call:
#
# Level 1: T(n)
#
# Level 2:2T(n/2),2T(n/2)+n
#
# Level 3: 4T(n/4),4T(n/4)+n/2,4T(n/4)+n/2,4T(n/4)+n and so on.
#
# This forms a binary tree, where each node has two children. The depth of the tree is
# n, and at each level, the number of nodes is a power of 2.
#
# Now, let's sum up the work done at each level:
#
# Level 1: n
#
# Level 2: 2(n/2)+n
#
# Level 3: 4(n/4)+n/2+n/2+n, and so on
#
# Generalizing this pattern, the work done at level i is 2^i * (n/2^n) + n/2^(i-1)
#
# Now, summing up over all levels (i=0 to n), we get the total work done:
#
# T(n)= n. log2(n)+n.∑1/2^(i-1)
#
# Therefore, the solution to the given recurrence relation is:
#
# 0(nlogn)
